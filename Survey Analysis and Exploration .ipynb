# %% [markdown]
# # Use multiple visualisation libraries (PixieDust & Brunel) for fast analysis and exploration of survey results.
#
#
# This notebook runs on Python with Spark 2.0.

# %% [markdown]
# ## 1. Import Libraries
# Before you can use the PixieDust and Brunel libraries they must be imported into the notebook. We'll use some Pandas as well.

# %%
import pixiedust
import brunel
import pandas as pd

# %% [markdown]
# ## 2. Load the data
# We will load our survey data from its connected catalog Db2 Warehouse source into a PySpark DataFrame for analysis.

# %%
# The code was removed by DSX for sharing.
# Out:
# Row(SURVEY_DATE=u'4/08/2016', SURVEY_ID=u'1828515415', DEPARTMENT=u'Sales', OVERALL_SATISFACTION_COMMENT=u"The gentleman that I spoke to that I just spoke to was very knowledgeable and everything that I asked him. He knew all the answers and he actually had solutions to the questions as it relates to do if you could change, I mean the system broke down on me one evening, which is completely erased all the work and everything that I had in my car which is about 30 to 35 items and it's completely kicked me off and walked me out and would let me log back in until the next morning. The other issue is that my business and is tax exempt and for some reason tax exemption is such a difficult thing when ordering on Acme's for the Pros. And I think that would be a problem for other contractors have to go through multiple different avenues in order to get the channels pass it off so that their customers and not being charged sales tax twice.", OVERALL_SATISFACTION=6, LEVEL_OF_EFFORT=4, LIKELY_T
# ...

# %% [markdown]
# ## 3. View and Visualise the Data wih PixieDust
# Use the PixieDust display function to interactively analyse and display the data. Note that PixieDust does all the hard work, we simply pass the dataframe to it.

# %%
display(survey)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#     height: inherit;
# ...

# %%
display(survey)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure9fbfeaa6" class="pd_save" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %%
display(survey)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure89aabd2b" class="pd_save" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     if ( !window.Bokeh && !window.autoload){
#                         window.autoload=true;
#
# (function(root) {
#   function now() {
#     return new Date();
#   }
#
#   var force = true;
#
#   if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#     root._bokeh_onload_callbacks = [];
#     root._bokeh_is_loading = undefined;
#   }
#
#
#
#   if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
# ...

# %% [markdown]
# ## 4. View and Visualise the Data wih Brunel
# Use the Brunel library to visualise survey data. Refer to online documentatiuon and samples here: http://brunel.mybluemix.net/docs/

# %%
#convert to a Pandas DataFrame
survey_pandas = survey.toPandas()

# %%
#Number of Survey Responses per Department 
# %brunel data('survey_pandas') bar x(DEPARTMENT) y(#count) :: width=500, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/eeb76212-f1d5-49d9-9b42-815d7a4b071c/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/eeb76212-f1d5-49d9-9b42-815d7a4b071c/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
#Look at the relationship between Overall Satisfaction and Agent Empathy
# %brunel data('survey_pandas') x(DEPARTMENT) y(OVERALL_SATISFACTION) color(AGENT_EMPATHY) :: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/eeb76212-f1d5-49d9-9b42-815d7a4b071c/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/eeb76212-f1d5-49d9-9b42-815d7a4b071c/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...
